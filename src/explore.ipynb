# %% [markdown]
# # Explore here

# %% [markdown]
# 1. Realizar un EDA

# %%
# Your code here

import pandas as pd

raw_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/linear-regression-project-tutorial/main/medical_insurance_cost.csv")

raw_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
import pandas as pd

filtered_data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/linear-regression-project-tutorial/main/medical_insurance_cost.csv")

filtered_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# No hay ningún NaN

# %%
filtered_data.drop(["region", "charges"], axis = 1, inplace = True)
filtered_data
# Out:
#       age     sex     bmi  children smoker
# 0      19  female  27.900         0    yes
# 1      18    male  33.770         1     no
# 2      28    male  33.000         3     no
# 3      33    male  22.705         0     no
# 4      32    male  28.880         0     no
# ...   ...     ...     ...       ...    ...
# 1333   50    male  30.970         3     no
# 1334   18  female  31.920         0     no
# 1335   18  female  36.850         0     no
# 1336   21  female  25.800         0     no
# 1337   61  female  29.070         0    yes
#
# [1338 rows x 5 columns]

# %% [markdown]
# # Análisis sobre variables categóricas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Análisis sobre variables categóricas

fig, axis = plt.subplots(2, 2, figsize = (15, 10))

sns.histplot(ax = axis[0,0], data = filtered_data, x = "sex")
sns.histplot(ax = axis[0,1], data = filtered_data, x = "smoker")

plt.tight_layout()

plt.show()

# %% [markdown]
# # Análisis sobre variables numéricas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Análisis sobre variables numéricas

fig, axis = plt.subplots(2, 2, figsize = (10, 7), gridspec_kw={'height_ratios': [6, 1]})

sns.histplot(ax = axis[0, 0], data = filtered_data, x = "age").set(xlabel = None)
sns.boxplot(ax = axis[1, 0], data = filtered_data, x = "age")
sns.histplot(ax = axis[0, 1], data = filtered_data, x = "children").set(xlabel = None, ylabel = None)
sns.boxplot(ax = axis[1, 1], data = filtered_data, x = "children")

plt.tight_layout()

plt.show()

# %% [markdown]
# Vemos como muchos usuarios son de menos de 30 años y esto puede estar relacionado con le hecho de tener hijos puesto que la gran mayoría o no tienen hijos o tienen 1.

# %% [markdown]
# # Análisis numérico-numérico

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Análisis numérico-numérico

fig, axis = plt.subplots(2, figsize = (12, 12))
sns.regplot(ax = axis[0], data = filtered_data, x = "children", y = "age")
sns.heatmap(filtered_data[["children", "age" ]].corr(), annot = True, fmt = ".2f", ax = axis[1], cbar = False)
# Out:
# <Axes: >

# %% [markdown]
# # Análisis categórico-categórico

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Análisis categórico-categórico

fig, axis = plt.subplots(figsize = (5, 5))

sns.countplot(data = filtered_data, x = "sex", hue = "smoker")

plt.tight_layout()

plt.show()

# %%
raw_data["sex"] = pd.factorize(raw_data["sex"])[0]
raw_data["smoker"] = pd.factorize(raw_data["smoker"])[0]
raw_data["region"] = pd.factorize(raw_data["region"])[0]

fig, axes = plt.subplots(figsize=(15, 15))

sns.heatmap(raw_data[["age", "sex", "bmi", "children", "smoker", "region", "charges"]].corr(), annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %%
sns.pairplot(data = raw_data)

# %%
filtered_data
# Out:
#       age     sex     bmi  children smoker
# 0      19  female  27.900         0    yes
# 1      18    male  33.770         1     no
# 2      28    male  33.000         3     no
# 3      33    male  22.705         0     no
# 4      32    male  28.880         0     no
# ...   ...     ...     ...       ...    ...
# 1333   50    male  30.970         3     no
# 1334   18  female  31.920         0     no
# 1335   18  female  36.850         0     no
# 1336   21  female  25.800         0     no
# 1337   61  female  29.070         0    yes
#
# [1338 rows x 5 columns]

# %%
fig, axes = plt.subplots(2, 2, figsize = (15, 15))

sns.boxplot(ax = axes[0, 0], data = filtered_data, y = "age")
sns.boxplot(ax = axes[0, 1], data = filtered_data, y = "children")

plt.tight_layout()

plt.show()

# %%
raw_data["sex_n"] = pd.factorize(raw_data["sex"])[0]
raw_data["smoker_n"] = pd.factorize(raw_data["smoker"])[0]
raw_data["region_n"] = pd.factorize(raw_data["region"])[0]

fig, axis = plt.subplots(figsize = (10, 6))

sns.heatmap(raw_data[["age", "sex_n", "bmi", "children", "smoker_n", "region_n", "charges"]].corr(), annot = True, fmt = ".2f")

plt.tight_layout()

plt.show()

# %% [markdown]
# En este mapa de calor podemos ver como los años de las personas y los costes que tienen, tienen una fuerte relación y a medida que aumenta uno, sube el otro.
# Por otra parte, un índice de masa corporal más alto está relacionado con mayores costos.
# Por último, vemos que la relación más fuerte y negativa en este heatmap. Indica que fumar tiene un impacto significativo en los costos.

# %% [markdown]
# # Future Engineering

# %%
raw_data_con_outliers = raw_data.copy()
raw_data_sin_outliers = raw_data.copy()

# %%
raw_data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.795217
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     1.000000
# 50%      39.000000     1.000000    30.400000     1.000000     1.000000
# 75%      51.000000     1.000000    34.693750     2.000000     1.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges        sex_n     smoker_n     region_n
# count  1338.000000   1338.000000  1338.000000  1338.000000  1338.000000
# mean      1.484305  13270.422265     0.505232     0.795217     1.484305
# std       1.104885  12110.011237     0.500160     0.403694     1.104885
# ...

# %%
fig, axis = plt.subplots(3, 3, figsize = (25, 20))

sns.boxplot(ax = axis[0, 0], data = raw_data, y = "age")
sns.boxplot(ax = axis[0, 1], data = raw_data, y = "bmi")
sns.boxplot(ax = axis[0, 2], data = raw_data, y = "children")
sns.boxplot(ax = axis[1, 0], data = raw_data, y = "charges")
sns.boxplot(ax = axis[1, 1], data = raw_data, y = "sex_n")
sns.boxplot(ax = axis[1, 2], data = raw_data, y = "smoker_n")
sns.boxplot(ax = axis[2, 0], data = raw_data, y =  "region_n")

plt.tight_layout()

plt.show()

# %% [markdown]
# # Remove outliers

# %%
bmi_stats = raw_data["bmi"].describe()
bmi_stats
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
# Le vammos a quitar los outliers a charges y bmi
# BMI STATS

bmi_iqr = bmi_stats["75%"] - bmi_stats["25%"]
upper_limit = bmi_stats["75%"] + 2 * bmi_iqr
lower_limit = bmi_stats ["25%"] - 2 * bmi_iqr

print (f"El límite superior para encontrar outliers en la columna bmi es {upper_limit}, el límite inferior es {lower_limit} y el límite intercuartil es {bmi_iqr}")
# Out:
# El límite superior para encontrar outliers en la columna bmi es 51.48875, el límite inferior es 9.501249999999999 y el límite intercuartil es 8.3975

# %%
charges_stats = raw_data["charges"].describe()

charges_stats
# Out:
# count     1338.000000
# mean     13270.422265
# std      12110.011237
# min       1121.873900
# 25%       4740.287150
# 50%       9382.033000
# 75%      16639.912515
# max      63770.428010
# Name: charges, dtype: float64

# %%
# CHARGES STATS

charges_iqr = charges_stats["75%"] - charges_stats["25%"]
upper_limit_charges = charges_stats["75%"] + 2 * charges_iqr
lower_limit_charges = charges_stats["25%"] - 2 * charges_iqr

print(f"El límite superior para encontrar outliers en la columna charges es {upper_limit_charges}, el límite inferior es {lower_limit_charges} y el límite intercuartil es {charges_iqr}")
# Out:
# El límite superior para encontrar outliers en la columna charges es 40439.163245, el límite inferior es -19058.96358 y el límite intercuartil es 11899.625365

# %%
raw_data_con_outliers.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# sex_n       0
# smoker_n    0
# region_n    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

num_variables = ["age", "bmi", "children", "charges"]

x_con_outliers = raw_data_con_outliers.drop("smoker", axis = 1,)[num_variables]
y = raw_data_con_outliers["smoker"]
x_sin_outliers = raw_data_sin_outliers.drop("smoker", axis = 1)[num_variables]
# NO ACABO DE ENTENDER MUY BIEN ESTE PASO

x_train_con_outliers, x_test_con_outliers, y_train, y_test = train_test_split(x_con_outliers, y, test_size = 0.2, random_state = 42)
x_train_sin_outliers, x_test_sin_outliers, _, _ = train_test_split(x_sin_outliers, y, test_size = 0.2, random_state = 42)

y_train.to_csv("../data/processed/y_train.csv", index = False)
y_test.to_csv("../data/processed/y_test.csv", index = False)

x_train_con_outliers.head()
# Out:
#       age    bmi  children      charges
# 560    46  19.95         2   9193.83850
# 1285   47  24.32         0   8534.67180
# 1142   52  24.86         0  27117.99378
# 969    39  34.32         5   8596.82780
# 486    54  21.47         3  12475.35130

# %% [markdown]
# Normalización!!!

# %%
from sklearn.preprocessing import StandardScaler
from pickle import dump
import pandas as pd

scaler_con_outliers_norm = StandardScaler()
scaler_con_outliers_norm.fit(x_train_con_outliers)
scaler_sin_outliers_norm = StandardScaler()
scaler_sin_outliers_norm.fit(x_train_sin_outliers)

x_train_con_norm = pd.DataFrame(scaler_con_outliers_norm.transform(x_train_con_outliers), index = x_train_con_outliers.index, columns = num_variables)

x_test_con_norm = pd.DataFrame(scaler_con_outliers_norm.transform(x_test_con_outliers), index = x_test_con_outliers.index, columns = num_variables)

x_train_sin_norm = pd.DataFrame(scaler_sin_outliers_norm.transform(x_train_sin_outliers), index = x_train_sin_outliers.index, columns = num_variables)

x_test_sin_norm = pd.DataFrame(scaler_sin_outliers_norm.transform(x_test_sin_outliers), index = x_test_sin_outliers.index, columns = num_variables)

x_train_sin_norm.head()

dump(scaler_con_outliers_norm, open("../data/processed/scaler_con_outliers_norm.sav", "wb"))
dump(scaler_sin_outliers_norm, open("../data/processed/scaler_sin_outliers_norm.sav", "wb"))

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from pickle import dump

# CON OUTLIERS

scaler_MinMax_con_outliers = MinMaxScaler()
scaler_MinMax_con_outliers.fit(x_train_con_outliers)
scaler_MinMax_sin_outliers = MinMaxScaler()
scaler_MinMax_sin_outliers.fit(x_train_sin_outliers)

x_train_con_scal = scaler_MinMax_con_outliers.transform(x_train_con_outliers)
x_train_con_scal = pd.DataFrame(x_train_con_scal, index = x_train_con_outliers.index, columns = num_variables)

x_test_con_scal = scaler_MinMax_con_outliers.transform(x_test_con_outliers)
x_test_con_scal = pd.DataFrame(x_test_con_scal, index = x_test_con_outliers.index, columns = num_variables)


# SIN OUTLIERS

x_train_sin_scal = scaler_MinMax_sin_outliers.transform(x_train_sin_outliers)
x_train_sin_scal = pd.DataFrame(x_train_sin_scal, index = x_train_sin_outliers.index, columns = num_variables)

x_test_sin_scal = scaler_MinMax_sin_outliers.transform(x_test_sin_outliers)
x_test_sin_scal = pd.DataFrame(x_test_sin_scal, index = x_test_sin_outliers.index, columns = num_variables)

dump(scaler_MinMax_con_outliers, open("../data/processed/scaler_MinMax_con_outliers.sav", "wb"))
dump(scaler_MinMax_sin_outliers, open("../data/processed/scaler_MinMax_sin_outliers.sav", "wb"))

x_train_con_scal.head()
# Out:
#            age       bmi  children   charges
# 560   0.608696  0.107345       0.4  0.131313
# 1285  0.630435  0.224913       0.0  0.120590
# 1142  0.739130  0.239440       0.0  0.422901
# 969   0.456522  0.493947       1.0  0.121601
# 486   0.782609  0.148238       0.6  0.184696

# %%
from sklearn.feature_selection import f_classif, SelectKBest

# CON OUTLIERS
selection_model_con_outliers = SelectKBest(f_classif, k = 5)
selection_model_con_outliers.fit(x_train_con_outliers, y_train)
column_names = selection_model_con_outliers.get_support()

x_train_sel_con_outliers = pd.DataFrame(selection_model_con_outliers.transform(x_train_con_outliers), columns = x_train_con_outliers.columns.values[column_names])
x_test_sel_con_outliers = pd.DataFrame(selection_model_con_outliers.transform(x_test_con_outliers), columns = x_test_con_outliers.columns.values[column_names])

dump(selection_model_con_outliers, open("../data/processed/selection_model_con_outliers.sav", "wb"))

x_train_sel_con_norm = x_train_con_norm[list(x_train_sel_con_outliers.columns)]
x_train_sel_con_scal = x_train_con_scal[list(x_train_sel_con_outliers.columns)]

x_test_sel_con_norm = x_test_con_norm[list(x_test_sel_con_outliers.columns)]
x_test_sel_con_scal = x_test_con_scal[list(x_test_sel_con_outliers.columns)]


# SIN OUTLIERS
selection_model_sin_outliers = SelectKBest(f_classif, k = 5)
selection_model_sin_outliers.fit(x_train_sin_outliers, y_train)
column_names = selection_model_sin_outliers.get_support()

x_train_sel_sin_outliers = pd.DataFrame(selection_model_sin_outliers.transform(x_train_sin_outliers), columns = x_train_sin_outliers.columns.values[column_names])
x_test_sel_sin_outliers = pd.DataFrame(selection_model_sin_outliers.transform(x_test_sin_outliers), columns = x_test_sin_outliers.columns.values[column_names])

dump(selection_model_sin_outliers, open("../data/processed/selection_model_sin_outliers.sav", "wb"))

x_train_sel_sin_norm = x_train_con_norm[x_train_sel_sin_outliers.columns]
x_train_sel_sin_scal = x_train_sin_scal[x_train_sel_sin_outliers.columns]

x_test_sel_sin_norm = x_test_sin_norm[x_test_sel_sin_outliers.columns]
x_test_sel_sin_scal = x_test_sin_scal[x_test_sel_sin_outliers.columns]
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/feature_selection/_univariate_selection.py:776: UserWarning: k=5 is greater than n_features=4. All the features will be returned.
#   warnings.warn(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/feature_selection/_univariate_selection.py:776: UserWarning: k=5 is greater than n_features=4. All the features will be returned.
#   warnings.warn(

# %%
import pandas as pd

# TRAIN CON OUTLIERS 

x_train_con_norm.to_csv("../data/processed/x_train_con_norm.csv", index=False)
x_train_con_scal.to_csv("../data/processed/x_train_con_scal.csv", index=False)
x_train_sin_norm.to_csv("../data/processed/x_train_sin_norm.csv", index=False)
x_train_sin_scal.to_csv("../data/processed/x_train_sin_scal.csv", index=False)

# TEST SIN OUTLIERS 

x_test_con_norm.to_csv("../data/processed/x_test_con_norm.csv", index=False)
x_test_con_scal.to_csv("../data/processed/x_test_con_scal.csv", index=False)
x_test_sin_norm.to_csv("../data/processed/x_test_sin_norm.csv", index=False)
x_test_sin_scal.to_csv("../data/processed/x_test_sin_scal.csv", index=False)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
#  7   sex_n     1338 non-null   int64
#  8   smoker_n  1338 non-null   int64
#  9   region_n  1338 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 104.7 KB

# %%
dfs_train = {
    "x_train_sel_con_outliers" : x_train_sel_con_outliers,
    "x_train_sel_con_outliers" : x_train_sel_con_outliers,
    "x_train_sel_con_norm" : x_train_sel_con_norm,
    "x_train_sel_sin_norm" : x_train_sel_sin_norm,
    "x_train_sel_con_scal" : x_train_sel_con_scal,
    "x_train_sel_sin_scal" : x_train_sel_sin_scal
}

dfs_test = {
    "x_test_sel_con_outliers" : x_test_sel_con_outliers,
    "x_test_sel_con_outliers" : x_test_sel_con_outliers,
    "x_test_sel_con_norm" : x_test_sel_con_norm,
    "x_test_sel_sin_norm" : x_test_sel_sin_norm,
    "x_test_sel_con_scal" : x_test_sel_con_scal,
    "x_test_sel_sin_scal" : x_test_sel_sin_scal 
}

for name, df in dfs_train.items():
    df.to_csv(f"../data/processed/{name}.csv", index = False)
    
for name, df in dfs_test.items():
    df.to_csv(f"../data/processed/{name}.csv", index = False)

# %% [markdown]
# Machine Learning (Linear Regression)

# %%
train, test = [], []

for name, df in dfs_train.items():
    train.append(df)

for name, df in dfs_test.items():
    test.append(df)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
import warnings
from sklearn.metrics import root_mean_squared_error

results = []

for index in range(len(train)):
    model = LinearRegression()
    train_df = train[index]
    model.fit(train_df, y_train)
    y_test_pred = model.predict(test[index])

    results.append(
        {
            "index" : index,
            "df_train" : list(dfs_train.keys())[index],
            "Coeficiente" : model.coef_,
            "MAE" : mean_absolute_error(y_test, y_test_pred).round(2),
            "RMSE" : round(root_mean_squared_error(y_test, y_test_pred), 2),
            "R2_score" : round(r2_score(y_test, y_test_pred), 5)
        }
    )

results = sorted(results, key = lambda x: x["RMSE"])
best_ind = results[0]["index"]
best_df_train = results[0]["df_train"]

results
# Out:
# [{'index': 0,
#   'df_train': 'x_train_sel_con_outliers',
#   'Coeficiente': array([ 8.15361668e-03,  9.76166413e-03,  1.11373539e-02, -2.99802598e-05]),
#   'MAE': np.float64(0.12),
#   'RMSE': np.float64(0.21),
#   'R2_score': 0.73835},
#  {'index': 1,
#   'df_train': 'x_train_sel_con_norm',
#   'Coeficiente': array([ 0.11470004,  0.05896593,  0.01353651, -0.36017963]),
#   'MAE': np.float64(0.12),
#   'RMSE': np.float64(0.21),
#   'R2_score': 0.73835},
#  {'index': 2,
#   'df_train': 'x_train_sel_sin_norm',
#   'Coeficiente': array([ 0.11470004,  0.05896593,  0.01353651, -0.36017963]),
#   'MAE': np.float64(0.12),
#   'RMSE': np.float64(0.21),
#   'R2_score': 0.73835},
#  {'index': 3,
#   'df_train': 'x_train_sel_con_scal',
#   'Coeficiente': array([ 0.37506637,  0.36284106,  0.05568677, -1.84291653]),
#   'MAE': np.float64(0.12),
#   'RMSE': np.float64(0.21),
#   'R2_score': 0.73835},
#  {'index': 4,
#   'df_train': 'x_train_sel_sin_scal',
# ...
